# %%
import pandas as pd
import matplotlib
dados = pd.read_csv('A150850189_28_143_208.csv', encoding='ISO-8859-1', skiprows=3, sep=';', thousands='.', decimal=',', skipfooter=12)
print(dados)
# Out:
#       Unidade da Federação  1992/Mar  1992/Abr  1993/Mai  1993/Dez  1994/Jan  \
# 0              11 Rondônia         -         -         -         -         -
# 1                  12 Acre         -         -         -         -         -
# 2              13 Amazonas         -         -         -         -         -
# 3               14 Roraima         -         -         -         -         -
# 4                  15 Pará         -         -         -         -         -
# 5                 16 Amapá         -         -         -         -         -
# 6             17 Tocantins         -         -         -         -         -
# 7              21 Maranhão         -         -         -         -         -
# 8                 22 Piauí         -         -         -         -         -
# 9                 23 Ceará         -         -         -         -         -
# 10  24 Rio Grande do Norte         -         -         -         -         -
# ...

# %%
dados[["2008/Ago", "2008/Set"]]
# Out:
#         2008/Ago      2008/Set
# 0   2.938286e+06  2.843931e+06
# 1   1.886872e+06  2.084885e+06
# 2   8.331764e+06  8.148090e+06
# 3   1.045291e+06  1.003741e+06
# 4   2.325915e+07  2.366769e+07
# 5   1.550341e+06  1.550167e+06
# 6   5.213290e+06  5.201401e+06
# 7   1.460987e+07  1.531788e+07
# 8   1.064592e+07  1.103794e+07
# 9   2.930482e+07  3.043503e+07
# 10  1.081284e+07  1.125868e+07
# 11  1.267377e+07  1.279064e+07
# 12  3.170530e+07  3.070388e+07
# 13  9.262768e+06  9.228202e+06
# 14  4.543252e+06  4.525677e+06
# 15  4.325454e+07  4.285127e+07
# 16  8.037412e+07  8.241688e+07
# 17  1.238407e+07  1.248695e+07
# 18  4.250217e+07  4.306646e+07
# 19  1.800974e+08  1.802116e+08
# 20  5.669900e+07  5.809199e+07
# 21  2.888785e+07  3.072572e+07
# 22  5.623376e+07  5.791017e+07
# 23  9.602843e+06  1.027247e+07
# 24  8.987812e+06  8.843062e+06
# 25  2.107020e+07  2.142608e+07
# 26  1.154845e+07  1.242258e+07

# %%
dados[["2008/Ago", "2008/Set"]].head()
# Out:
#       2008/Ago     2008/Set
# 0   2938286.29   2843930.91
# 1   1886871.84   2084884.80
# 2   8331763.97   8148089.92
# 3   1045291.11   1003740.89
# 4  23259148.28  23667690.01

# %%
dados.head()
# Out:
#   Unidade da Federação 1992/Mar 1992/Abr 1993/Mai 1993/Dez 1994/Jan 1994/Fev  \
# 0          11 Rondônia        -        -        -        -        -        -
# 1              12 Acre        -        -        -        -        -        -
# 2          13 Amazonas        -        -        -        -        -        -
# 3           14 Roraima        -        -        -        -        -        -
# 4              15 Pará        -        -        -        -        -        -
#
#   1994/Mai 1994/Ago 1994/Nov  ...     2021/Jan     2021/Fev     2021/Mar  \
# 0        -        -        -  ...  10045624.39  10677245.18  18147121.02
# 1        -        -        -  ...   4175526.06   5282655.42   5699597.78
# 2        -        -        -  ...  27406458.57  22341042.63  27923786.94
# 3        -        -        -  ...   3557821.99   4172285.82   5427226.70
# 4        -        -        -  ...  39042349.46  37113440.70  49625416.13
#
# ...

# %%
dados.columns
# Out:
# Index(['Unidade da Federação', '1992/Mar', '1992/Abr', '1993/Mai', '1993/Dez',
#        '1994/Jan', '1994/Fev', '1994/Mai', '1994/Ago', '1994/Nov',
#        ...
#        '2021/Jan', '2021/Fev', '2021/Mar', '2021/Abr', '2021/Mai', '2021/Jun',
#        '2021/Jul', '2021/Ago', '2021/Set', 'Total'],
#       dtype='object', length=293)

# %%
def is_numeric_column(series):
    return pd.to_numeric(series, errors='coerce').notna().all()

numeric_cols = dados.columns[dados.apply(is_numeric_column, axis=0)]
dados_numericos = dados[numeric_cols]

colunas_usaveis = dados_numericos.mean().index.tolist()
print(colunas_usaveis)
# Out:
# ['2007/Ago', '2007/Set', '2007/Out', '2007/Nov', '2007/Dez', '2008/Jan', '2008/Fev', '2008/Mar', '2008/Abr', '2008/Mai', '2008/Jun', '2008/Jul', '2008/Ago', '2008/Set', '2008/Out', '2008/Nov', '2008/Dez', '2009/Jan', '2009/Fev', '2009/Mar', '2009/Abr', '2009/Mai', '2009/Jun', '2009/Jul', '2009/Ago', '2009/Set', '2009/Out', '2009/Nov', '2009/Dez', '2010/Jan', '2010/Fev', '2010/Mar', '2010/Abr', '2010/Mai', '2010/Jun', '2010/Jul', '2010/Ago', '2010/Set', '2010/Out', '2010/Nov', '2010/Dez', '2011/Jan', '2011/Fev', '2011/Mar', '2011/Abr', '2011/Mai', '2011/Jun', '2011/Jul', '2011/Ago', '2011/Set', '2011/Out', '2011/Nov', '2011/Dez', '2012/Jan', '2012/Fev', '2012/Mar', '2012/Abr', '2012/Mai', '2012/Jun', '2012/Jul', '2012/Ago', '2012/Set', '2012/Out', '2012/Nov', '2012/Dez', '2013/Jan', '2013/Fev', '2013/Mar', '2013/Abr', '2013/Mai', '2013/Jun', '2013/Jul', '2013/Ago', '2013/Set', '2013/Out', '2013/Nov', '2013/Dez', '2014/Jan', '2014/Fev', '2014/Mar', '2014/Abr', '2014/Mai', '2014/Jun', '
# ...

# %%
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis[:5]
# Out:
# ['Unidade da Federação', '2007/Ago', '2007/Set', '2007/Out', '2007/Nov']

# %%
dados_usaveis = dados[colunas_usaveis]
dados_usaveis.head()
# Out:
#   Unidade da Federação   2007/Ago   2007/Set    2007/Out    2007/Nov  \
# 0          11 Rondônia    4209.37   16397.03   133645.19   346912.84
# 1              12 Acre   10470.07   14001.71    86200.85   301323.68
# 2          13 Amazonas   35752.72   45570.64   416012.30  2020381.79
# 3           14 Roraima    4785.91   11858.63    43852.67   369328.51
# 4              15 Pará  181159.29  433414.74  1893197.50  5105406.44
#
#       2007/Dez     2008/Jan     2008/Fev     2008/Mar     2008/Abr  ...  \
# 0    711758.31   1829559.71   1940792.63   1955721.68   2143353.81  ...
# 1    769612.36   1731744.62   1743978.66   2057439.02   2057829.69  ...
# 2   5949408.99  11419210.08   7934652.10   8641517.13   8531576.49  ...
# 3    470676.43    808448.39    771687.83    876091.18    896952.53  ...
# 4  13162823.43  21762104.16  20126081.01  22149375.82  23436682.75  ...
#
#       2020/Dez     2021/Jan     2021/Fev     2021/Mar     2021/Abr  \
# ...

# %%
dados_usaveis = dados_usaveis.set_index("Unidade da Federação")
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis["2019/Ago"].head()
# Out:
# Unidade da Federação
# 11 Rondônia     8909111.89
# 12 Acre         2981072.98
# 13 Amazonas    16493719.52
# 14 Roraima      3181321.82
# 15 Pará        36462011.47
# Name: 2019/Ago, dtype: float64

# %%
dados_usaveis.loc["12 Acre"]
# Out:
# 2007/Ago    1.047007e+04
# 2007/Set    1.400171e+04
# 2007/Out    8.620085e+04
# 2007/Nov    3.013237e+05
# 2007/Dez    7.696124e+05
#                 ...
# 2021/Mai    4.326882e+06
# 2021/Jun    3.458187e+06
# 2021/Jul    2.302711e+06
# 2021/Ago    1.196755e+06
# Total       4.752903e+08
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.iloc[1]
# Out:
# 2007/Ago    1.047007e+04
# 2007/Set    1.400171e+04
# 2007/Out    8.620085e+04
# 2007/Nov    3.013237e+05
# 2007/Dez    7.696124e+05
#                 ...
# 2021/Mai    4.326882e+06
# 2021/Jun    3.458187e+06
# 2021/Jul    2.302711e+06
# 2021/Ago    1.196755e+06
# Total       4.752903e+08
# Name: 12 Acre, Length: 170, dtype: float64

# %%
dados_usaveis.plot(figsize=(12,6))
# Out:
# <Axes: xlabel='Unidade da Federação'>

# %%
dados_usaveis.T.head()
# Out:
# Unidade da Federação  11 Rondônia    12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37   10470.07     35752.72     4785.91
# 2007/Set                 16397.03   14001.71     45570.64    11858.63
# 2007/Out                133645.19   86200.85    416012.30    43852.67
# 2007/Nov                346912.84  301323.68   2020381.79   369328.51
# 2007/Dez                711758.31  769612.36   5949408.99   470676.43
#
# Unidade da Federação      15 Pará   16 Amapá  17 Tocantins  21 Maranhão  \
# 2007/Ago                181159.29   33672.74       4113.76    385330.18
# 2007/Set                433414.74  104822.98      76633.06   1018352.93
# 2007/Out               1893197.50  118378.28     343702.61   2277717.78
# 2007/Nov               5105406.44  226661.18    1068685.94   4334468.23
# 2007/Dez              13162823.43  844019.90    3022200.87   8832514.85
#
# Unidade da Federação    22 Piauí     23 Ceará  ...  32 Espírito Santo  \
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T.tail()
# Out:
# Unidade da Federação   11 Rondônia       12 Acre   13 Amazonas    14 Roraima  \
# 2021/Mai              1.765986e+07  4.326882e+06  2.397354e+07  3.681418e+06
# 2021/Jun              1.443590e+07  3.458187e+06  2.217540e+07  3.475206e+06
# 2021/Jul              1.183444e+07  2.302711e+06  2.161494e+07  3.320808e+06
# 2021/Ago              7.371335e+06  1.196755e+06  1.380696e+07  2.907871e+06
# Total                 1.088060e+09  4.752903e+08  2.061943e+09  3.525463e+08
#
# Unidade da Federação       15 Pará      16 Amapá  17 Tocantins   21 Maranhão  \
# 2021/Mai              5.090723e+07  5.672087e+06  1.016178e+07  5.532468e+07
# 2021/Jun              4.387659e+07  5.469150e+06  6.349488e+06  5.195857e+07
# 2021/Jul              3.371808e+07  4.136951e+06  4.610171e+06  3.777543e+07
# 2021/Ago              2.083787e+07  1.875242e+06  2.304080e+06  2.577967e+07
# Total                 4.968812e+09  3.371820e+08  1.110345e+09  4.161326e+09
#
# ...

# %%
dados_usaveis = dados_usaveis.drop("Total", axis=1)
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis.T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.T
# Out:
# Unidade da Federação  11 Rondônia     12 Acre  13 Amazonas  14 Roraima  \
# 2007/Ago                  4209.37    10470.07     35752.72     4785.91
# 2007/Set                 16397.03    14001.71     45570.64    11858.63
# 2007/Out                133645.19    86200.85    416012.30    43852.67
# 2007/Nov                346912.84   301323.68   2020381.79   369328.51
# 2007/Dez                711758.31   769612.36   5949408.99   470676.43
# ...                           ...         ...          ...         ...
# 2021/Abr              17753851.45  5002272.59  24515920.09  4192540.54
# 2021/Mai              17659855.79  4326882.24  23973537.71  3681417.80
# 2021/Jun              14435903.47  3458187.11  22175398.40  3475205.55
# 2021/Jul              11834435.10  2302711.01  21614943.55  3320807.96
# 2021/Ago               7371334.84  1196754.85  13806958.66  2907871.07
#
# Unidade da Federação      15 Pará    16 Amapá  17 Tocantins  21 Maranhão  \
# ...

# %%
##### Desafio P1 #####

import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.figure as figure

axis = dados_usaveis.T.plot(figsize=(14,6))
plt.xlabel("Ano/Mês",
           fontsize=14)
plt.ylabel("Valor * 1e9",
           fontsize=14)
plt.title("Valor por unidade da Federação",
          fontsize=30,
          horizontalalignment = 'center',
          family='serif')
plt.legend(loc='upper right', ncols=3)
plt.show()

# %%
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
dados_usaveis.T.columns[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis.index[:5]
# Out:
# Index(['11 Rondônia', '12 Acre', '13 Amazonas', '14 Roraima', '15 Pará'], dtype='object', name='Unidade da Federação')

# %%
dados_usaveis[:7].T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis.sample(n=7)
# Out:
#                         2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 33 Rio de Janeiro      469469.34   921646.57   2994664.57   7250528.08
# 41 Paraná              554800.22  1431708.01   4630402.44  11120030.79
# 53 Distrito Federal    191951.47   769966.25   2165619.56   3813256.48
# 31 Minas Gerais        971394.37  2861781.50  10018011.35  21730281.63
# 12 Acre                 10470.07    14001.71     86200.85    301323.68
# 52 Goiás               179395.82   418053.58   1198730.25   2712117.54
# 50 Mato Grosso do Sul  199556.12   573675.41   1069816.66   1995899.52
#
#                           2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 33 Rio de Janeiro      13627123.27  2.521758e+08  44128159.73  42907909.35
# 41 Paraná              28790722.87  5.808133e+07  48855046.46  55611791.07
# 53 Distrito Federal     7121965.42  1.056109e+07  10215956.80  11627918.26
# ...

# %%
dados_usaveis.sample(7).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
import numpy as np

np.random.seed(234789)
dados_usaveis.sample(n=7)
# Out:
#                          2007/Ago    2007/Set     2007/Out     2007/Nov  \
# Unidade da Federação
# 22 Piauí                220788.25   353468.67   1078182.68   2406035.32
# 14 Roraima                4785.91    11858.63     43852.67    369328.51
# 21 Maranhão             385330.18  1018352.93   2277717.78   4334468.23
# 31 Minas Gerais         971394.37  2861781.50  10018011.35  21730281.63
# 24 Rio Grande do Norte  134605.36   272088.08    684678.30   1695824.89
# 42 Santa Catarina       693955.05  1092964.12   3562300.82   7578502.38
# 13 Amazonas              35752.72    45570.64    416012.30   2020381.79
#
#                            2007/Dez      2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 22 Piauí                 4929772.93  1.137542e+07   9711680.20  10428191.09
# 14 Roraima                470676.43  8.084484e+05    771687.83    876091.18
# 21 Maranhão              8832514.85  2.155160e+07  13452263.93  14750895.33
# ...

# %%
dados_usaveis.sample(n=7).T.plot(figsize=(12,6))
# Out:
# <Axes: >

# %%
dados_usaveis["Total"] = dados_usaveis.sum(axis = 1)
dados_usaveis.head()
# Out:
#                        2007/Ago   2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 11 Rondônia             4209.37   16397.03   133645.19   346912.84
# 12 Acre                10470.07   14001.71    86200.85   301323.68
# 13 Amazonas            35752.72   45570.64   416012.30  2020381.79
# 14 Roraima              4785.91   11858.63    43852.67   369328.51
# 15 Pará               181159.29  433414.74  1893197.50  5105406.44
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 11 Rondônia             711758.31   1829559.71   1940792.63   1955721.68
# 12 Acre                 769612.36   1731744.62   1743978.66   2057439.02
# 13 Amazonas            5949408.99  11419210.08   7934652.10   8641517.13
# 14 Roraima              470676.43    808448.39    771687.83    876091.18
# 15 Pará               13162823.43  21762104.16  20126081.01  22149375.82
#
# ...

# %%
#### Desafio P2 ####
np.random.seed(337284)
dados_dos_7_estados = dados_usaveis.sample(7)
regioes = ["Nordeste", "Nordeste", "Centro", "Nordeste", "Norte", "Norte", "Norte"]
dados_dos_7_estados["Região"] = regioes
dados_dos_7_estados["Total"] = dados_dos_7_estados.sum(axis=1, numeric_only=True)
dados_dos_7_estados.head(7).sort_values(by='Total', ascending=False)
# Out:
#                        2007/Ago    2007/Set    2007/Out    2007/Nov  \
# Unidade da Federação
# 29 Bahia              135146.36   448349.75  1382038.11  3348779.62
# 26 Pernambuco         400640.85  1088340.42  2973553.48  6699828.82
# 52 Goiás              179395.82   418053.58  1198730.25  2712117.54
# 27 Alagoas            104243.75   174024.90   595544.54  1125396.73
# 11 Rondônia             4209.37    16397.03   133645.19   346912.84
# 12 Acre                10470.07    14001.71    86200.85   301323.68
# 16 Amapá               33672.74   104822.98   118378.28   226661.18
#
#                          2007/Dez     2008/Jan     2008/Fev     2008/Mar  \
# Unidade da Federação
# 29 Bahia              11948984.56  74456787.96  33410124.06  41329594.35
# 26 Pernambuco         16919031.39  51279301.86  26222079.10  30716361.81
# 52 Goiás               9293914.78  76052094.77  18149374.27  20992213.03
# 27 Alagoas             2564966.65  16623799.85   8112220.30   9210505.56
# ...
